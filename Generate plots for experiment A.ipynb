# %%
# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

df = pd.read_csv('point_01_SM.csv')

# %%
df.head()
# Out:
#     Length    LCI  Actual    HCI
# 0    4-6mm  71.69   100.0  100.0
# 1    6-8mm  84.67   100.0  100.0
# 2   8-10mm  77.91   100.0  100.0
# 3  10-12mm  86.71   100.0  100.0
# 4  12-14mm  85.41   100.0  100.0

# %%
df = pd.read_csv('point_01_SM.csv')
fig, ax = plt.subplots()
plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]],color="red")
plt.xticks(rotation=90)
plt.xlabel("Length")
plt.ylabel("Percentage that were not MUA")
plt.title("0.01% MS-222 (% not MUA)",fontweight="bold")
plt.tight_layout()
plt.savefig('point1SM')
plt.savefig('point1SM.eps')

# %%
df = pd.read_csv('point_008_SM.csv')
fig, ax = plt.subplots()
plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]], color="green")

plt.xticks(rotation=90)
plt.xlabel("Length")
plt.ylabel("Percentage that were not MUA")
plt.title("0.008% MS-222 (% not MUA)",fontweight="bold")
plt.tight_layout()
plt.savefig('point08SM')
plt.savefig('point08SM.eps')

# %%
df = pd.read_csv('point_009_SM.csv')
fig, ax = plt.subplots()

fig=plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]],color="orange")
plt.xticks(rotation=90)

plt.xlabel("Length")
plt.ylabel("Percentage that were not MUA")
plt.title("0.009% MS-222 (% not MUA)",fontweight="bold")
plt.tight_layout()
plt.savefig('point09SM')
plt.savefig('point09SM.eps')

# %%
df = pd.read_csv('point_01_rec.csv')
fig, ax = plt.subplots()
plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]],color="red")
plt.xticks(rotation=90)
plt.xlabel("Length")
plt.ylabel("Percentage that recovered")
plt.title("0.01% MS-222 (% Recovered)",fontweight="bold")
plt.tight_layout()
plt.savefig('point1rec')
plt.savefig('point1rec.eps')

# %%
df = pd.read_csv('point_008_rec.csv')
fig, ax = plt.subplots()
plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]], color="green")

plt.xticks(rotation=90)
plt.xlabel("Length")
plt.ylabel("Percentage that recovered")
plt.title("0.008% MS-222 (% Recovered)",fontweight="bold")
plt.tight_layout()
plt.savefig('point08rec')
plt.savefig('point08rec.eps')

# %%
df = pd.read_csv('point_009_rec.csv')
fig, ax = plt.subplots()

fig=plt.bar(df["Length"],df["Actual"],yerr=[df["Actual"]-df["LCI"],df["HCI"]-df["Actual"]],color="orange")
plt.xticks(rotation=90)

plt.xlabel("Length")
plt.ylabel("Percentage that recovered")
plt.title("0.009% MS-222 (% Recovered)",fontweight="bold")
plt.tight_layout()
plt.savefig('point09rec')
plt.savefig('point09rec.eps')
